# %%
import pandas as pd

# %%
crimeDB = pd.read_csv('MCI_2014_to_2019.csv')

# %%
crimeDB.head()
# Out:
#               X             Y  Index_ event_unique_id          occurrencedate  \
# 0 -8.840549e+06  5.431712e+06     201  GO-20141301077  2014/01/07 05:00:00+00
# 1 -8.840549e+06  5.431712e+06     202  GO-20141301077  2014/01/07 05:00:00+00
# 2 -8.840549e+06  5.431712e+06     203  GO-20141301077  2014/01/07 05:00:00+00
# 3 -8.840549e+06  5.431712e+06     204  GO-20141301077  2014/01/07 05:00:00+00
# 4 -8.839881e+06  5.413806e+06     205  GO-20141300854  2014/01/07 05:00:00+00
#
#              reporteddate premisetype  ucr_code  ucr_ext              offence  \
# 0  2014/01/07 05:00:00+00       Other      1420      100  Assault With Weapon
# 1  2014/01/07 05:00:00+00       Other      1420      100  Assault With Weapon
# 2  2014/01/07 05:00:00+00       Other      1420      100  Assault With Weapon
# 3  2014/01/07 05:00:00+00       Other      1420      100  Assault With Weapon
# 4  2014/01/07 05:00:00+00  Commercial      2120      200                  B&E
#
# ...

# %%
crimeDB2 = crimeDB.drop(columns=['X', 'Y', 'Index_', 'occurrencedate', 'ucr_code', 'ucr_ext', 'reporteddayofyear',
                      'occurrencedate', 'occurrenceyear', 'occurrencemonth', 'occurrencedayofyear', 
                      'occurrencedayofweek', 'occurrencehour'] )
crimeDB2.head()
# Out:
#   event_unique_id            reporteddate premisetype              offence  \
# 0  GO-20141301077  2014/01/07 05:00:00+00       Other  Assault With Weapon
# 1  GO-20141301077  2014/01/07 05:00:00+00       Other  Assault With Weapon
# 2  GO-20141301077  2014/01/07 05:00:00+00       Other  Assault With Weapon
# 3  GO-20141301077  2014/01/07 05:00:00+00       Other  Assault With Weapon
# 4  GO-20141300854  2014/01/07 05:00:00+00  Commercial                  B&E
#
#    reportedyear reportedmonth  reportedday reporteddayofweek  reportedhour  \
# 0          2014       January            7        Tuesday               22
# 1          2014       January            7        Tuesday               22
# 2          2014       January            7        Tuesday               22
# 3          2014       January            7        Tuesday               22
# 4          2014       January            7        Tuesday               21
#
# ...

# %%
df1 = crimeDB2.drop_duplicates("event_unique_id")
df1.head()
# Out:
#   event_unique_id            reporteddate premisetype              offence  \
# 0  GO-20141301077  2014/01/07 05:00:00+00       Other  Assault With Weapon
# 4  GO-20141300854  2014/01/07 05:00:00+00  Commercial                  B&E
# 5  GO-20141310106  2014/01/09 05:00:00+00   Apartment                  B&E
# 6  GO-20141351494  2014/01/16 05:00:00+00   Apartment              Assault
# 7  GO-20141351916  2014/01/16 05:00:00+00  Commercial              Assault
#
#    reportedyear reportedmonth  reportedday reporteddayofweek  reportedhour  \
# 0          2014       January            7        Tuesday               22
# 4          2014       January            7        Tuesday               21
# 5          2014       January            9        Thursday              11
# 6          2014       January           16        Thursday               0
# 7          2014       January           16        Thursday               2
#
#    occurrenceday              MCI Division  Hood_ID  \
# ...

# %%
df1.to_csv("Toronto_crime.csv")

# %%
df1.dtypes
# Out:
# event_unique_id       object
# reporteddate          object
# premisetype           object
# offence               object
# reportedyear           int64
# reportedmonth         object
# reportedday            int64
# reporteddayofweek     object
# reportedhour           int64
# occurrenceday        float64
# MCI                   object
# Division              object
# Hood_ID                int64
# Neighbourhood         object
# Lat                  float64
# Long                 float64
# ObjectId               int64
# dtype: object

# %%
df1['offence'].nunique()
# Out:
# 48

# %%
df1['offence'].unique()
# Out:
# array(['Assault With Weapon', 'B&E', 'Assault', 'Robbery - Business',
#        'Assault - Resist/ Prevent Seiz', 'Robbery With Weapon',
#        'Robbery - Other', 'Theft Over', "B&E W'Intent",
#        'Robbery - Swarming', 'Robbery - Mugging',
#        'Discharge Firearm - Recklessly', 'Assault Bodily Harm',
#        'Theft From Motor Vehicle Over', 'Robbery - Home Invasion',
#        'Aggravated Assault', 'Use Firearm / Immit Commit Off',
#        'Robbery - Taxi', 'Robbery - Purse Snatch',
#        'Discharge Firearm With Intent', 'Unlawfully In Dwelling-House',
#        'Assault Peace Officer', 'Robbery - Financial Institute',
#        'Pointing A Firearm', 'Theft Over - Shoplifting',
#        'Robbery - Delivery Person', 'B&E Out',
#        'Assault - Force/Thrt/Impede', 'Theft From Mail / Bag / Key',
#        'Assault Peace Officer Wpn/Cbh', 'Administering Noxious Thing',
#        'Crim Negligence Bodily Harm', 'Robbery - Vehicle Jacking',
# ...
